# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# %%
#helper functions

def read_file(filename, pit_state=False):
    change = []
    data = []
    for i in range(len(filename.sheet_names)):
        if pit_state==True:
            if i==0:
                change = pd.read_excel(filename, 0)
            else:
                data.append(pd.read_excel(filename, i))
        else:
            data.append(pd.read_excel(filename,i))
    if pit_state==True: return change, data
    return data

# %% [markdown]
# ## Data

# %%
#PIT State Data
xls = pd.ExcelFile('Data/2007-2022-PIT-Counts-by-State.xlsx')
PIT_State_Change, PIT_State_Data = read_file(xls, True)

xls = pd.ExcelFile('Data/2011-2022-PIT-Veteran-Counts-by-State.xlsx')
PIT_Veteran_Change, PIT_Veteran_State = read_file(xls, True)

#PIT CoC Data
xls = pd.ExcelFile('Data/2007-2022-PIT-Counts-by-CoC.xlsx')
PIT_CoC_Data = read_file(xls)

xls = pd.ExcelFile('Data/2011-2022-PIT-Veteran-Counts-by-CoC.xlsx')
PIT_Veteran_State = read_file(xls)

#HIC State Data
xls = pd.ExcelFile('Data/2007-2022-HIC-Counts-by-State.xlsx')
HIC_State_Data = read_file(xls)

#HIC CoC Data
xls = pd.ExcelFile('Data/2007-2022-HIC-Counts-by-CoC.xlsx')
HIC_CoC_Data = read_file(xls)

#Funding Data
xls = pd.ExcelFile('Data/All-States-2020-2021-Funding-Report.xlsx')
Funding_Data = read_file(xls)

# %% [markdown]
# ## Data Cleaning

# %%
PIT_State_Change.head()
# Out:
#   State Change in Total Homelessness, 2021-2022  \
# 0    AK                                0.190354
# 1    AL                                0.467919
# 2    AR                                0.149603
# 3    AS
# 4    AZ                                1.482234
#
#   Change in Total Homelessness, 2020-2022  \
# 0                                0.190354
# 1                                0.119666
# 2                                0.039307
# 3
# 4                                0.234448
#
#   Change in Total Homelessness, 2019-2022  \
# 0                                 0.21657
# 1                                0.150567
# 2                               -0.094958
# 3
# 4                                0.354352
#
#   Change in Total Homelessness, 2018-2022  \
# 0                                0.150794
# 1                                0.092603
# 2                               -0.093289
# 3
# 4                                0.373847
#
#   Change in Total Homelessness, 2017-2022  \
# 0                                0.257453
# 1                               -0.010809
# 2                               -0.003243
# 3
# 4                                0.514809
#
#   Change in Total Homelessness, 2016-2022  \
# 0                                0.195876
# 1                               -0.087327
# 2                               -0.001624
# 3
# 4                                0.396209
#
#   Change in Total Homelessness, 2015-2022  \
# 0                                0.186094
# 1                               -0.054912
# 2                               -0.039453
# 3
# 4                                0.369543
#
#   Change in Total Homelessness, 2014-2022  \
# 0                                0.300448
# 1                               -0.177373
# 2                               -0.162466
# 3
# 4                                0.291377
#
#   Change in Total Homelessness, 2013-2022  \
# 0                                0.192189
# 1                               -0.199829
# 2                               -0.354932
# 3
# 4                                0.283185
#
#   Change in Total Homelessness, 2012-2022  \
# 0                                0.212755
# 1                               -0.279708
# 2                               -0.416469
# 3
# 4                                0.199168
#
#   Change in Total Homelessness, 2011-2022  \
# 0                                0.090226
# 1                               -0.324937
# 2                               -0.281834
# 3
# 4                                 0.29027
#
#   Change in Total Homelessness, 2010-2022  \
# 0                                0.245303
# 1                               -0.379424
# 2                               -0.109703
# 3
# 4                               -0.011524
#
#   Change in Total Homelessness, 2009-2022  \
# 0                                0.164659
# 1                               -0.382895
# 2                               -0.137798
# 3
# 4                               -0.079342
#
#   Change in Total Homelessness, 2008-2022  \
# 0                                0.409477
# 1                               -0.303508
# 2                               -0.244547
# 3
# 4                                0.085282
#
#   Change in Total Homelessness, 2007-2022
# 0                                0.412911
# 1                               -0.311812
# 2                               -0.358968
# 3
# 4                               -0.074628

# %%
PIT_State_Data[0].head()
# Out:
#   State  Number of CoCs Overall Homeless, 2022  \
# 0    AK               2                   2320
# 1    AL               8                   3752
# 2    AR               5                   2459
# 3    AS               0
# 4    AZ               3                  13553
#
#   Overall Homeless - Under 18, 2022 Overall Homeless - Age 18 to 24, 2022  \
# 0                               328                                   203
# 1                               790                                   217
# 2                               243                                   243
# 3
# 4                              1723                                  1084
#
#   Overall Homeless - Over 24, 2022 Overall Homeless - Female, 2022  \
# 0                             1789                             892
# 1                             2745                            1633
# 2                             1973                             861
# 3
# 4                            10746                            4884
#
#   Overall Homeless - Male, 2022 Overall Homeless - Transgender, 2022  \
# 0                          1417                                    8
# 1                          2099                                   13
# 2                          1589                                    4
# 3
# 4                          8594                                   37
#
#   Overall Homeless - Gender that is not Singularly Female or Male, 2022  ...  \
# 0                                                  3                     ...
# 1                                                  4                     ...
# 2                                                  5                     ...
# 3                                                                        ...
# 4                                                 35                     ...
#
#   Overall Homeless Parenting Youth Age 18-24, 2022  \
# 0                                               11
# 1                                               41
# 2                                               23
# 3
# 4                                              100
#
#   Sheltered ES Homeless Parenting Youth Age 18-24, 2022  \
# 0                                                  7
# 1                                                 16
# 2                                                  2
# 3
# 4                                                 40
#
#   Sheltered TH Homeless Parenting Youth Age 18-24, 2022  \
# 0                                                  4
# 1                                                 13
# 2                                                  0
# 3
# 4                                                 30
#
#   Sheltered Total Homeless Parenting Youth Age 18-24, 2022  \
# 0                                                 11
# 1                                                 29
# 2                                                  2
# 3
# 4                                                 70
#
#   Unsheltered Homeless Parenting Youth Age 18-24, 2022  \
# 0                                                  0
# 1                                                 12
# 2                                                 21
# 3
# 4                                                 30
#
#   Overall Homeless Children of Parenting Youth, 2022  \
# 0                                                 10
# 1                                                 53
# 2                                                 23
# 3
# 4                                                112
#
#   Sheltered ES Homeless Children of Parenting Youth, 2022  \
# 0                                                  6
# 1                                                 24
# 2                                                  2
# 3
# 4                                                 40
#
#   Sheltered TH Homeless Children of Parenting Youth, 2022  \
# 0                                                  4
# 1                                                 14
# 2                                                  0
# 3
# 4                                                 38
#
#   Sheltered Total Homeless Children of Parenting Youth, 2022  \
# 0                                                 10
# 1                                                 38
# 2                                                  2
# 3
# 4                                                 78
#
#   Unsheltered Homeless Children of Parenting Youth, 2022
# 0                                                  0
# 1                                                 15
# 2                                                 21
# 3
# 4                                                 34
#
# [5 rows x 575 columns]
