# %%
import pandas as pd
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
#helper function
def read_file(filename):
    data = []
    for i in range(len(filename.sheet_names)):
            data.append(pd.read_excel(filename,i))
    return data

# %%
xls = pd.ExcelFile('Cleaned Data/PIT_State_vF.xlsx')
PIT_State_vF = read_file(xls)
#PIT_State_vF[0]

# %%
xls = pd.ExcelFile('Cleaned Data/HIC_State_vF.xlsx')
HIC_State_vF = read_file(xls)
#HIC_State_vF[0].head()
#HIC_State_vF[0]["State"].all() == PIT_State_vF[0]["State"].all()

# %%
xls = pd.ExcelFile('Cleaned Data/PIT_State_Change_vF.xlsx')
PIT_State_Change_vF = read_file(xls)

# %%
#copy = pd.concat([PIT_State_vF[0]["Overall Homeless, 2022"], HIC_State_vF[0]], axis = 1)
copy = pd.concat([PIT_State_Change_vF[0]["Change in Total Homelessness, 2021-2022"], HIC_State_vF[0]], axis = 1)
#copy.head()

# %%
corr_mat = copy.corr(numeric_only = True)
corr_mat["Change in Total Homelessness, 2021-2022"]
# Out:
# Change in Total Homelessness, 2021-2022                      1.000000
# Total Year-Round Beds (ES, TH, SH)                          -0.035819
# Total Non-DV Year-Round Beds (ES, TH, SH)                   -0.035741
# Total HMIS Year-Round Beds (ES, TH, SH)                     -0.035757
# HMIS Participation Rate for Year-Round Beds (ES, TH, SH)    -0.587368
# Total Year-Round Beds (ES)                                  -0.035634
# Total Year-Round Beds (TH)                                  -0.036132
# Total Year-Round Beds (SH)                                  -0.035236
# Total Units for Households with Children (ES, TH, SH)       -0.035746
# Total Beds for Households with Children (ES, TH, SH)        -0.035884
# Total Beds for Households without Children (ES, TH, SH)     -0.035730
# Total Beds for Households with only Children (ES, TH, SH)   -0.034782
# Dedicated Veteran Beds (ES, TH, SH)                         -0.036160
# Dedicated Youth Beds (ES, TH, SH)                           -0.035643
# Total Year-Round Beds (ES).1                                -0.035634
# Total Non-DV Year-Round Beds (ES)                           -0.035546
# Total HMIS Year-Round Beds (ES)                             -0.035534
# HMIS Participation Rate for Year-Round Beds (ES)            -0.536206
# Total Seasonal Beds (ES)                                    -0.036570
# Total Overflow Beds (ES)                                    -0.036270
# Total Units for Households with Children (ES)               -0.035443
# Total Beds for Households with Children (ES)                -0.035607
# Total Beds for Households without Children (ES)             -0.035588
# Total Beds for Households with only Children (ES)           -0.034347
# Dedicated Veteran Beds (ES)                                 -0.036378
# Dedicated Youth Beds (ES)                                   -0.035249
# Total Year-Round Beds (TH).1                                -0.036132
# Total Non-DV Year-Round Beds (TH)                           -0.036064
# Total HMIS Year-Round Beds (TH)                             -0.036088
# HMIS Participation Rate for Year-Round Beds (TH)             0.126284
# Total Units for Households with Children (TH)               -0.036084
# Total Beds for Households with Children (TH)                -0.036162
# Total Beds for Households without Children (TH)             -0.036039
# Total Beds for Households with only Children (TH)           -0.036520
# Dedicated Veteran Beds (TH)                                 -0.036175
# Dedicated Youth Beds (TH)                                   -0.035811
# Total Year-Round Beds (SH).1                                -0.035236
# Total Non-DV Year-Round Beds (SH)                           -0.035159
# Total HMIS Year-Round Beds (SH)                             -0.035560
# HMIS Participation Rate for Year-Round Beds (SH)             0.149946
# Total Units for Households with Children (SH)                     NaN
# Total Beds for Households with Children (SH)                      NaN
# Total Beds for Households without Children (SH)             -0.035236
# Total Beds for Households with only Children (SH)                 NaN
# Dedicated Veteran Beds (SH)                                 -0.034420
# Dedicated Youth Beds (SH)                                   -0.026346
# Total Year-Round Beds (RRH)                                 -0.035838
# Total Non-DV Year-Round Beds (RRH)                          -0.035718
# Total HMIS Year-Round Beds (RRH)                            -0.035702
# HMIS Participation Rate for Year-Round Beds (RRH)            0.195956
# Total Units for Households with Children (RRH)              -0.035954
# Total Beds for Households with Children (RRH)               -0.036189
# Total Beds for Households without Children (RRH)            -0.035086
# Total Beds for Households with only Children (RRH)          -0.033423
# Dedicated Veteran Beds (RRH)                                -0.035981
# Dedicated Youth Beds (RRH)                                  -0.036304
# Total Year-Round Beds (PSH)                                 -0.035921
# Total Non-DV Year-Round Beds (PSH)                          -0.035919
# Total HMIS Year-Round Beds (PSH)                            -0.035978
# HMIS Participation Rate for Year-Round Beds (PSH)            0.283314
# Total Units for Households with Children (PSH)              -0.036247
# Total Beds for Households with Children (PSH)               -0.036212
# Total Beds for Households without Children (PSH)            -0.035752
# Total Beds for Households with only Children (PSH)          -0.032160
# Dedicated Veteran Beds (PSH)                                -0.035702
# Dedicated Youth Beds (PSH)                                  -0.035237
# Dedicated Chronically Homeless Beds (PSH)                   -0.036187
# Total Year-Round Beds (OPH)                                 -0.035715
# Total Non-DV Year-Round Beds (OPH)                          -0.035716
# Total HMIS Year-Round Beds (OPH)                            -0.035156
# HMIS Participation Rate for Year-Round Beds (OPH)            0.020906
# Total Units for Households with Children (OPH)              -0.036204
# Total Beds for Households with Children (OPH)               -0.036094
# Total Beds for Households without Children (OPH)            -0.034999
# Total Beds for Households with only Children (OPH)          -0.030575
# Dedicated Veteran Beds (OPH)                                -0.035374
# Dedicated Youth Beds (OPH)                                  -0.033448
# Name: Change in Total Homelessness, 2021-2022, dtype: float64

# %%
copy.head()
# Out:
#    Change in Total Homelessness, 2021-2022 State  \
# 0                                 0.190354    AK
# 1                                 0.467919    AL
# 2                                 0.149603    AR
# 3                                 1.482234    AZ
# 4                                 1.984635    CA
#
#    Total Year-Round Beds (ES, TH, SH)  \
# 0                                3088
# 1                                2714
# 2                                2318
# 3                                6162
# 4                               68607
#
#    Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                       2547
# 1                                       2229
# 2                                       1787
# 3                                       5467
# 4                                      64427
#
#    Total HMIS Year-Round Beds (ES, TH, SH)  \
# 0                                     2439
# 1                                     1757
# 2                                     1117
# 3                                     5089
# 4                                    52234
#
#    HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             0.7898
# 1                                             0.6474
# 2                                             0.4819
# 3                                             0.8259
# 4                                             0.7614
#
#    Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# 0                        2615                         473
# 1                        2034                         646
# 2                        1920                         398
# 3                        4272                        1808
# 4                       52839                       15134
#
#    Total Year-Round Beds (SH)  \
# 0                           0
# 1                          34
# 2                           0
# 3                          82
# 4                         634
#
#    Total Units for Households with Children (ES, TH, SH)  \
# 0                                                205
# 1                                                349
# 2                                                195
# 3                                                807
# 4                                               9282
#
#    Total Beds for Households with Children (ES, TH, SH)  \
# 0                                                692
# 1                                               1027
# 2                                                778
# 3                                               2564
# 4                                              26344
#
#    Total Beds for Households without Children (ES, TH, SH)  \
# 0                                               2344
# 1                                               1632
# 2                                               1514
# 3                                               3534
# 4                                              41848
#
#    Total Beds for Households with only Children (ES, TH, SH)  \
# 0                                                 52
# 1                                                 55
# 2                                                 26
# 3                                                 64
# 4                                                415
#
#    Dedicated Veteran Beds (ES, TH, SH)  Dedicated Youth Beds (ES, TH, SH)  \
# 0                                   12                                153
# 1                                  204                                121
# 2                                  108                                 77
# 3                                  544                                185
# 4                                 3189                               3300
#
#    Total Year-Round Beds (ES).1  Total Non-DV Year-Round Beds (ES)  \
# 0                          2615                               2180
# 1                          2034                               1756
# 2                          1920                               1459
# 3                          4272                               3764
# 4                         52839                              50471
#
#    Total HMIS Year-Round Beds (ES)  \
# 0                             2096
# 1                             1422
# 2                              843
# 3                             3592
# 4                            41697
#
#    HMIS Participation Rate for Year-Round Beds (ES)  Total Seasonal Beds (ES)  \
# 0                                            0.8015                       138
# 1                                            0.6991                        44
# 2                                            0.4391                         0
# 3                                            0.8408                        68
# 4                                            0.7891                      2032
#
#    Total Overflow Beds (ES)  Total Units for Households with Children (ES)  \
# 0                        15                                            122
# 1                        38                                            225
# 2                       104                                            157
# 3                       132                                            507
# 4                      4255                                           6834
#
#    Total Beds for Households with Children (ES)  \
# 0                                           431
# 1                                           713
# 2                                           626
# 3                                          1739
# 4                                         19649
#
#    Total Beds for Households without Children (ES)  \
# 0                                             2137
# 1                                             1282
# 2                                             1268
# 3                                             2469
# 4                                            32811
#
#    Total Beds for Households with only Children (ES)  \
# 0                                                 47
# 1                                                 39
# 2                                                 26
# 3                                                 64
# 4                                                379
#
#    Dedicated Veteran Beds (ES)  Dedicated Youth Beds (ES)  \
# 0                            0                         96
# 1                          128                         93
# 2                           46                         54
# 3                           53                         97
# 4                          524                       1277
#
#    Total Year-Round Beds (TH).1  Total Non-DV Year-Round Beds (TH)  \
# 0                           473                                367
# 1                           646                                439
# 2                           398                                328
# 3                          1808                               1621
# 4                         15134                              13324
#
#    Total HMIS Year-Round Beds (TH)  \
# 0                              343
# 1                              301
# 2                              274
# 3                             1415
# 4                            10084
#
#    HMIS Participation Rate for Year-Round Beds (TH)  \
# 0                                            0.7252
# 1                                            0.4659
# 2                                            0.6884
# 3                                            0.7826
# 4                                            0.6663
#
#    Total Units for Households with Children (TH)  \
# 0                                             83
# 1                                            124
# 2                                             38
# 3                                            300
# 4                                           2448
#
#    Total Beds for Households with Children (TH)  \
# 0                                           261
# 1                                           314
# 2                                           152
# 3                                           825
# 4                                          6695
#
#    Total Beds for Households without Children (TH)  \
# 0                                              207
# 1                                              316
# 2                                              246
# 3                                              983
# 4                                             8403
#
#    Total Beds for Households with only Children (TH)  \
# 0                                                  5
# 1                                                 16
# 2                                                  0
# 3                                                  0
# 4                                                 36
#
#    Dedicated Veteran Beds (TH)  Dedicated Youth Beds (TH)  \
# 0                           12                         57
# 1                           76                         28
# 2                           62                         23
# 3                          422                         88
# 4                         2157                       2023
#
#    Total Year-Round Beds (SH).1  Total Non-DV Year-Round Beds (SH)  \
# 0                             0                                  0
# 1                            34                                 34
# 2                             0                                  0
# 3                            82                                 82
# 4                           634                                632
#
#    Total HMIS Year-Round Beds (SH)  \
# 0                                0
# 1                               34
# 2                                0
# 3                               82
# 4                              453
#
#    HMIS Participation Rate for Year-Round Beds (SH)  \
# 0                                               NaN
# 1                                            1.0000
# 2                                               NaN
# 3                                            1.0000
# 4                                            0.7145
#
#    Total Units for Households with Children (SH)  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    Total Beds for Households with Children (SH)  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    Total Beds for Households without Children (SH)  \
# 0                                                0
# 1                                               34
# 2                                                0
# 3                                               82
# 4                                              634
#
#    Total Beds for Households with only Children (SH)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Dedicated Veteran Beds (SH)  Dedicated Youth Beds (SH)  \
# 0                            0                          0
# 1                            0                          0
# 2                            0                          0
# 3                           69                          0
# 4                          508                          0
#
#    Total Year-Round Beds (RRH)  Total Non-DV Year-Round Beds (RRH)  \
# 0                          374                                 323
# 1                          597                                 575
# 2                          348                                 345
# 3                         2613                                2543
# 4                        29487                               28568
#
#    Total HMIS Year-Round Beds (RRH)  \
# 0                               323
# 1                               575
# 2                               340
# 3                              2543
# 4                             28094
#
#    HMIS Participation Rate for Year-Round Beds (RRH)  \
# 0                                             0.8636
# 1                                             0.9631
# 2                                             0.9770
# 3                                             0.9732
# 4                                             0.9528
#
#    Total Units for Households with Children (RRH)  \
# 0                                              37
# 1                                             121
# 2                                              69
# 3                                             522
# 4                                            5345
#
#    Total Beds for Households with Children (RRH)  \
# 0                                            137
# 1                                            380
# 2                                            166
# 3                                           1509
# 4                                          12989
#
#    Total Beds for Households without Children (RRH)  \
# 0                                               231
# 1                                               217
# 2                                               182
# 3                                              1104
# 4                                             16496
#
#    Total Beds for Households with only Children (RRH)  \
# 0                                                  6
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  2
#
#    Dedicated Veteran Beds (RRH)  Dedicated Youth Beds (RRH)  \
# 0                            83                          29
# 1                            46                          18
# 2                            92                           0
# 3                           382                         102
# 4                          2268                        1090
#
#    Total Year-Round Beds (PSH)  Total Non-DV Year-Round Beds (PSH)  \
# 0                         1090                                1090
# 1                         2410                                2410
# 2                          762                                 762
# 3                         8979                                8979
# 4                        72086                               71913
#
#    Total HMIS Year-Round Beds (PSH)  \
# 0                               683
# 1                              1875
# 2                               632
# 3                              8242
# 4                             55492
#
#    HMIS Participation Rate for Year-Round Beds (PSH)  \
# 0                                             0.6266
# 1                                             0.7780
# 2                                             0.8294
# 3                                             0.9179
# 4                                             0.7698
#
#    Total Units for Households with Children (PSH)  \
# 0                                              85
# 1                                             146
# 2                                             119
# 3                                             653
# 4                                            6922
#
#    Total Beds for Households with Children (PSH)  \
# 0                                            240
# 1                                            435
# 2                                            322
# 3                                           2492
# 4                                          19915
#
#    Total Beds for Households without Children (PSH)  \
# 0                                               850
# 1                                              1975
# 2                                               440
# 3                                              6487
# 4                                             52164
#
#    Total Beds for Households with only Children (PSH)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  7
#
#    Dedicated Veteran Beds (PSH)  Dedicated Youth Beds (PSH)  \
# 0                           386                          13
# 1                          1123                           7
# 2                           130                           0
# 3                          2224                          86
# 4                         23942                        1117
#
#    Dedicated Chronically Homeless Beds (PSH)  Total Year-Round Beds (OPH)  \
# 0                                        694                          279
# 1                                        757                           73
# 2                                        199                           22
# 3                                       2619                          698
# 4                                      24466                        18377
#
#    Total Non-DV Year-Round Beds (OPH)  Total HMIS Year-Round Beds (OPH)  \
# 0                                 279                                85
# 1                                  73                                73
# 2                                  22                                22
# 3                                 698                               419
# 4                               18235                             14878
#
#    HMIS Participation Rate for Year-Round Beds (OPH)  \
# 0                                             0.3047
# 1                                             1.0000
# 2                                             1.0000
# 3                                             0.6003
# 4                                             0.8096
#
#    Total Units for Households with Children (OPH)  \
# 0                                              23
# 1                                               6
# 2                                               5
# 3                                             148
# 4                                            2102
#
#    Total Beds for Households with Children (OPH)  \
# 0                                            106
# 1                                             20
# 2                                             12
# 3                                            482
# 4                                           6203
#
#    Total Beds for Households without Children (OPH)  \
# 0                                               173
# 1                                                53
# 2                                                10
# 3                                               216
# 4                                             12167
#
#    Total Beds for Households with only Children (OPH)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  7
#
#    Dedicated Veteran Beds (OPH)  Dedicated Youth Beds (OPH)
# 0                             0                           0
# 1                             9                           0
# 2                             0                           0
# 3                            23                           3
# 4                           526                         487

# %%
X = copy.drop(["State", "Change in Total Homelessness, 2021-2022", 
               "HMIS Participation Rate for Year-Round Beds (RRH)",
               "HMIS Participation Rate for Year-Round Beds (PSH)",
               "HMIS Participation Rate for Year-Round Beds (OPH)",
               "HMIS Participation Rate for Year-Round Beds (SH)",
               "HMIS Participation Rate for Year-Round Beds (TH)",
               "HMIS Participation Rate for Year-Round Beds (ES)",
               "HMIS Participation Rate for Year-Round Beds (ES, TH, SH)"], axis=1)
X = X.values
y = copy["Change in Total Homelessness, 2021-2022"]
y = y.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12345)

# %%
parameters = {"n_neighbors": range(1, 25), 'weights': ['uniform', 'distance']}
gridsearch = GridSearchCV(KNeighborsRegressor(), parameters)
gridsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(1, 25),
#                          'weights': ['uniform', 'distance']})

# %%
gridsearch.best_params_
# Out:
# {'n_neighbors': 10, 'weights': 'uniform'}

# %%
best_k = gridsearch.best_params_["n_neighbors"]
best_weights = gridsearch.best_params_["weights"]
bagged_knn = KNeighborsRegressor(n_neighbors=best_k, weights=best_weights)

# %%
bagging_model = BaggingRegressor(bagged_knn, n_estimators=100)

# %%
bagging_model.fit(X_train, y_train)
test_preds_grid = bagging_model.predict(X_test)
test_mse = mean_squared_error(y_test, test_preds_grid)
test_rmse = sqrt(test_mse)
test_rmse
# Out:
# 173.62727584112525

# %%
test_preds_grid
# Out:
# array([0.84543916, 0.21699044, 0.14810946, 0.62035698, 1.04098887,
#        0.17311554, 0.30990073, 0.2694761 , 0.44182161, 0.30197554,
#        0.19668318, 0.29225726])

# %%
y_test
# Out:
# array([1.1313870e-01, 7.4471100e-02, 3.9346700e-01, 7.0012240e-01,
#        6.0250000e+02, 1.3963855e+00, 1.2996530e-01, 7.6458800e-02,
#        9.8485850e-01, 1.1901659e+00, 1.1381483e+00, 2.8383800e-02])
